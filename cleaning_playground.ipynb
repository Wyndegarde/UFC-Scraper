# %%
import pandas as pd

# %% [markdown]
# # TO DOS
#
# - When scraping, change all columns to lowercase (already being done), remove punctuation, change % to 'percent' (symbol caused issues)
# - Only output the columns we need for

# %%
ufc_df = pd.read_csv("./ufc_scraper/data/raw_ufc_data.csv")

# %%
ufc_df.head()
# Out:
#            date                location         weight_class title_bout  \
# 0  May 20, 2023  Las Vegas, Nevada, USA  Women's Strawweight          N
# 1  May 20, 2023  Las Vegas, Nevada, USA         Middleweight          N
# 2  May 20, 2023  Las Vegas, Nevada, USA         Catch Weight          N
# 3  May 20, 2023  Las Vegas, Nevada, USA         Welterweight          N
# 4  May 20, 2023  Las Vegas, Nevada, USA          Lightweight          N
#
#   winner       red_Fighter       blue_Fighter  red_KD  blue_KD red_Sig. str.  \
# 0      W    Mackenzie Dern        Angela Hill       1        0    126 of 210
# 1      L  Edmen Shahbazyan  Anthony Hernandez       0        0      30 of 51
# 2      L      Emily Ducote      Loopy Godinez       0        0    112 of 270
# 3      L      Andre Fialho    Joaquin Buckley       0        1      22 of 51
# 4      W    Diego Ferreira    Michael Johnson       1        0      30 of 71
#
#    ...      blue_DOB blue_SLpM blue_Str. Acc. blue_SApM blue_Str. Def  \
# 0  ...  Jan 12, 1985      5.46            49%      4.97           61%
# 1  ...  Oct 18, 1993      4.33            62%      3.36           46%
# 2  ...  Sep 06, 1993      4.16            49%      3.77           62%
# 3  ...  Apr 27, 1994      3.76            32%      3.42           55%
# 4  ...  Jun 04, 1986      4.28            39%      3.91           58%
#
#   blue_TD Avg. blue_TD Acc. blue_TD Def. blue_Sub. Avg.     blue_record
# 0         0.54          29%          76%            0.1         15-13-0
# 1         6.79          57%          63%            2.9   11-2-0 (1 NC)
# 2         3.43          43%          81%            0.6          10-3-0
# 3         1.43          34%          66%            0.0          16-6-0
# 4         0.46          38%          80%            0.1         22-19-0
#
# [5 rows x 53 columns]

# %%
ufc_df.columns
# Out:
# Index(['date', 'location', 'weight_class', 'title_bout', 'winner',
#        'red_Fighter', 'blue_Fighter', 'red_KD', 'blue_KD', 'red_Sig. str.',
#        'blue_Sig. str.', 'red_Sig. str. %', 'blue_Sig. str. %',
#        'red_Total str.', 'blue_Total str.', 'red_Td', 'blue_Td', 'red_Td %',
#        'blue_Td %', 'red_Sub. att', 'blue_Sub. att', 'red_Rev.', 'blue_Rev.',
#        'red_Ctrl', 'blue_Ctrl', 'red_Height', 'red_Weight', 'red_Reach',
#        'red_STANCE', 'red_DOB', 'red_SLpM', 'red_Str. Acc.', 'red_SApM',
#        'red_Str. Def', 'red_TD Avg.', 'red_TD Acc.', 'red_TD Def.',
#        'red_Sub. Avg.', 'red_record', 'blue_Height', 'blue_Weight',
#        'blue_Reach', 'blue_STANCE', 'blue_DOB', 'blue_SLpM', 'blue_Str. Acc.',
#        'blue_SApM', 'blue_Str. Def', 'blue_TD Avg.', 'blue_TD Acc.',
#        'blue_TD Def.', 'blue_Sub. Avg.', 'blue_record'],
#       dtype='object')

# %%
clean_ufc_df = pd.read_csv("./ufc_scraper/data/clean_ufc_data.csv")

# %%
clean_ufc_df.head()
# Out:
#          date                location         weight_class title_bout winner  \
# 0  2023-05-20  Las Vegas, Nevada, USA  Women's Strawweight          N      W
# 1  2023-05-20  Las Vegas, Nevada, USA         Middleweight          N      L
# 2  2023-05-20  Las Vegas, Nevada, USA         Catch Weight          N      L
# 3  2023-05-20  Las Vegas, Nevada, USA         Welterweight          N      L
# 4  2023-05-20  Las Vegas, Nevada, USA          Lightweight          N      W
#
#         red_fighter       blue_fighter  red_kd  blue_kd  red_sig_str_%  ...  \
# 0    Mackenzie Dern        Angela Hill       1        0           0.60  ...
# 1  Edmen Shahbazyan  Anthony Hernandez       0        0           0.58  ...
# 2      Emily Ducote      Loopy Godinez       0        0           0.41  ...
# 3      Andre Fialho    Joaquin Buckley       0        1           0.43  ...
# 4    Diego Ferreira    Michael Johnson       1        0           0.42  ...
#
#    blue_td_landed  blue_td_percent  height_diff  reach_diff  red_age  \
# 0             0.0         0.000000          3.0       -2.54       30
# 1             6.0         0.400000          5.0        0.00       25
# 2             1.0         0.333333          0.0        5.08       29
# 3             2.0         0.666667          5.0       -5.08       29
# 4             0.0         0.000000         -3.0        2.54       38
#
#    blue_age  red_sig_strike_defence_percent blue_sig_strike_defence_percent  \
# 0        38                            0.39                            0.40
# 1        30                            0.29                            0.42
# 2        30                            0.47                            0.59
# 3        29                            0.71                            0.57
# 4        37                            0.45                            0.58
#
#   red_takedowns_defence_percent  blue_takedowns_defence_percent
# 0                          1.00                            0.67
# 1                          0.60                            0.00
# 2                          0.67                            1.00
# 3                          0.34                            1.00
# 4                          1.00                            1.00
#
# [5 rows x 73 columns]

# %%
clean_ufc_df.columns
# Out:
# Index(['date', 'location', 'weight_class', 'title_bout', 'winner',
#        'red_fighter', 'blue_fighter', 'red_kd', 'blue_kd', 'red_sig_str_%',
#        'blue_sig_str_%', 'red_td_%', 'blue_td_%', 'red_sub_att',
#        'blue_sub_att', 'red_rev', 'blue_rev', 'red_ctrl', 'blue_ctrl',
#        'red_height', 'red_weight', 'red_reach', 'red_stance', 'red_dob',
#        'red_slpm', 'red_str_acc', 'red_sapm', 'red_str_def', 'red_td_avg',
#        'red_td_acc', 'red_td_def', 'red_sub_avg', 'red_record', 'blue_height',
#        'blue_weight', 'blue_reach', 'blue_stance', 'blue_dob', 'blue_slpm',
#        'blue_str_acc', 'blue_sapm', 'blue_str_def', 'blue_td_avg',
#        'blue_td_acc', 'blue_td_def', 'blue_sub_avg', 'blue_record',
#        'red_sig_str_attempted', 'red_sig_str_landed', 'red_sig_str_percent',
#        'blue_sig_str_attempted', 'blue_sig_str_landed', 'blue_sig_str_percent',
#        'red_total_str_attempted', 'red_total_str_landed',
#        'red_total_str_percent', 'blue_total_str_attempted',
#        'blue_total_str_landed', 'blue_total_str_percent', 'red_td_attempted',
#        'red_td_landed', 'red_td_percent', 'blue_td_attempted',
#        'blue_td_landed', 'blue_td_percent', 'height_diff', 'reach_diff',
#        'red_age', 'blue_age', 'red_sig_strike_defence_percent',
#        'blue_sig_strike_defence_percent', 'red_takedowns_defence_percent',
#        'blue_takedowns_defence_percent'],
#       dtype='object')

# %% [markdown]
# ## Columns to keep
#
#        'date', 'location', 'weight_class', 'title_bout', 'winner',
#        'red_fighter', 'blue_fighter', 'red_kd', 'blue_kd', 'red_sub_att',
#        'blue_sub_att', 'red_rev', 'blue_rev', 'red_ctrl', 'blue_ctrl',
#        'red_height', 'red_weight', 'red_reach', 'red_stance', 'red_dob',
#        'red_record', 'blue_height',
#        'blue_weight', 'blue_reach', 'blue_stance', 'blue_dob', 'blue_record',
#        'red_sig_str_attempted', 'red_sig_str_landed', 'red_sig_str_percent',
#        'blue_sig_str_attempted', 'blue_sig_str_landed', 'blue_sig_str_percent',
#        'red_total_str_attempted', 'red_total_str_landed',
#        'red_total_str_percent', 'blue_total_str_attempted',
#        'blue_total_str_landed', 'blue_total_str_percent', 'red_td_attempted',
#        'red_td_landed', 'red_td_percent', 'blue_td_attempted',
#        'blue_td_landed', 'blue_td_percent', 'height_diff', 'reach_diff',
#        'red_age', 'blue_age', 'red_sig_strike_defence_percent',
#        'blue_sig_strike_defence_percent', 'red_takedowns_defence_percent',
#        'blue_takedowns_defence_percent'

# %%
clean_ufc_df[["red_td_%", "red_td_percent"]]
# Out:
#       red_td_%  red_td_percent
# 0         0.33        0.333333
# 1         1.00        1.000000
# 2         0.00        0.000000
# 3         0.00        0.000000
# 4         0.00        0.000000
# ...        ...             ...
# 6088      0.00        0.000000
# 6089      0.00        0.000000
# 6090      0.00        0.000000
# 6091      0.33        0.333333
# 6092      0.50        0.500000
#
# [6093 rows x 2 columns]

# %%
clean_ufc_df[[       'date', 'location', 'weight_class', 'title_bout', 'winner',
       'red_fighter', 'blue_fighter', 'red_kd', 'blue_kd', 'red_sub_att',
       'blue_sub_att', 'red_rev', 'blue_rev', 'red_ctrl', 'blue_ctrl',
       'red_height', 'red_weight', 'red_reach', 'red_stance', 'red_dob',
       'red_record', 'blue_height',
       'blue_weight', 'blue_reach', 'blue_stance', 'blue_dob', 'blue_record',
       'red_sig_str_attempted', 'red_sig_str_landed', 'red_sig_str_percent',
       'blue_sig_str_attempted', 'blue_sig_str_landed', 'blue_sig_str_percent',
       'red_total_str_attempted', 'red_total_str_landed',
       'red_total_str_percent', 'blue_total_str_attempted',
       'blue_total_str_landed', 'blue_total_str_percent', 'red_td_attempted',
       'red_td_landed', 'red_td_percent', 'blue_td_attempted',
       'blue_td_landed', 'blue_td_percent', 'height_diff', 'reach_diff',
       'red_age', 'blue_age', 'red_sig_strike_defence_percent',
       'blue_sig_strike_defence_percent', 'red_takedowns_defence_percent',
       'blue_takedowns_defence_percent']]
# Out:
#             date                             location         weight_class  \
# 0     2023-05-20               Las Vegas, Nevada, USA  Women's Strawweight
# 1     2023-05-20               Las Vegas, Nevada, USA         Middleweight
# 2     2023-05-20               Las Vegas, Nevada, USA         Catch Weight
# 3     2023-05-20               Las Vegas, Nevada, USA         Welterweight
# 4     2023-05-20               Las Vegas, Nevada, USA          Lightweight
# ...          ...                                  ...                  ...
# 6088  2023-06-10  Vancouver, British Columbia, Canada    Women's Flyweight
# 6089  2023-06-10  Vancouver, British Columbia, Canada         Bantamweight
# 6090  2023-06-10  Vancouver, British Columbia, Canada        Featherweight
# 6091  2023-06-10  Vancouver, British Columbia, Canada            Flyweight
# 6092  2023-06-10  Vancouver, British Columbia, Canada  Women's Strawweight
#
#      title_bout winner       red_fighter          blue_fighter  red_kd  \
# 0             N      W    Mackenzie Dern           Angela Hill       1
# 1             N      L  Edmen Shahbazyan     Anthony Hernandez       0
# 2             N      L      Emily Ducote         Loopy Godinez       0
# 3             N      L      Andre Fialho       Joaquin Buckley       0
# 4             N      W    Diego Ferreira       Michael Johnson       1
# ...         ...    ...               ...                   ...     ...
# 6088          N      L  Miranda Maverick  Jasmine Jasudavicius       0
# 6089          N      W    Aiemann Zahabi            Aoriqileng       1
# 6090          N      W       Kyle Nelson          Blake Bilder       0
# 6091          N      L      David Dvorak           Steve Erceg       0
# 6092          N      W     Diana Belbita        Maria Oliveira       0
#
#       blue_kd  red_sub_att  ...  blue_td_landed  blue_td_percent  height_diff  \
# 0           0            0  ...             0.0         0.000000          3.0
# 1           0            1  ...             6.0         0.400000          5.0
# 2           0            0  ...             1.0         0.333333          0.0
# 3           1            0  ...             2.0         0.666667          5.0
# 4           0            0  ...             0.0         0.000000         -3.0
# ...       ...          ...  ...             ...              ...          ...
# 6088        0            0  ...             1.0         1.000000        -10.0
# 6089        0            0  ...             0.0         0.000000          3.0
# 6090        0            0  ...             0.0         0.000000          7.0
# 6091        0            0  ...             3.0         0.750000         -8.0
# 6092        0            0  ...             2.0         0.400000          2.0
#
#      reach_diff red_age  blue_age red_sig_strike_defence_percent  \
# 0         -2.54      30        38                           0.39
# 1          0.00      25        30                           0.29
# 2          5.08      29        30                           0.47
# 3         -5.08      29        29                           0.71
# 4          2.54      38        37                           0.45
# ...         ...     ...       ...                            ...
# 6088      -7.62      26        34                           0.58
# 6089      -2.54      36        30                           0.00
# 6090       7.62      32        33                           0.63
# 6091       0.00      31        28                           0.62
# 6092      -2.54      27        26                           0.62
#
#       blue_sig_strike_defence_percent red_takedowns_defence_percent  \
# 0                                0.40                          1.00
# 1                                0.42                          0.60
# 2                                0.59                          0.67
# 3                                0.57                          0.34
# 4                                0.58                          1.00
# ...                               ...                           ...
# 6088                             0.51                          0.00
# 6089                             0.38                          1.00
# 6090                             0.54                          1.00
# 6091                             0.54                          0.25
# 6092                             0.50                          0.60
#
#      blue_takedowns_defence_percent
# 0                              0.67
# 1                              0.00
# 2                              1.00
# 3                              1.00
# 4                              1.00
# ...                             ...
# 6088                           1.00
# 6089                           1.00
# 6090                           1.00
# 6091                           0.67
# 6092                           0.50
#
# [6093 rows x 53 columns]

# %%
UFC_key_columns = ['date','red_fighter','blue_fighter','winner',
                                   'red_sig_strike_percent', 'blue_sig_strike_percent',
                                   'red_submission_attempts', 'blue_submission_attempts', 
                                   'red_STANCE', 'blue_STANCE', 'red_total_strikes_percent',
                                   'blue_total_strikes_percent', 'red_takedowns_percent',
                                   'blue_takedowns_percent', 'Height_diff', 'Reach_diff', 
                                   'red_age','blue_age','red_sig_strike_defence_percent',
                                   'blue_sig_strike_defence_percent', 'red_takedowns_defence_percent',
                                   'blue_takedowns_defence_percent']

# %%
import statsmodels.api as sm

# %%
sig_strike_model = sm.OLS(clean_ufc_df["red_sig_str_percent"], sm.add_constant(clean_ufc_df["blue_sig_str_percent"])).fit()

# %%
x = sig_strike_model.summary()

# %%
type(x)
# Out:
# statsmodels.iolib.summary.Summary

# %%
sig_strike_model.rsquared_adj
# Out:
# 0.0002982137719163003

# %%
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_repr_html_',
#  '_repr_latex_',
#  'add_extra_txt',
#  'add_table_2cols',
#  'add_table_params',
#  'as_csv',
#  'as_html',
#  'as_latex',
#  'as_text',
#  'extra_txt',
#  'tables']

# %%
y = x.tables

# %%
y[0][0][-1].data
# Out:
# '   0.000'

# %%
y[0].data
# Out:
# [['Dep. Variable:',
#   'red_sig_str_percent',
#   '  R-squared:         ',
#   '   0.000'],
#  ['Model:', 'OLS', '  Adj. R-squared:    ', '   0.000'],
#  ['Method:', 'Least Squares', '  F-statistic:       ', '   2.817'],
#  ['Date:', 'Sat, 26 Aug 2023', '  Prob (F-statistic):', '0.0933'],
#  ['Time:', '14:31:08', '  Log-Likelihood:    ', '  2615.4'],
#  ['No. Observations:', '  6093', '  AIC:               ', '  -5227.'],
#  ['Df Residuals:', '  6091', '  BIC:               ', '  -5213.'],
#  ['Df Model:', '     1', '                     ', ' '],
#  ['Covariance Type:', 'nonrobust', '                     ', ' ']]

# %%
type(y[0].data)
# Out:
# list

# %%
dir(y[0])
# Out:
# ['_Cell',
#  '_Row',
#  '__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_headers_stubs',
#  '_colwidths',
#  '_csv_fmt',
#  '_data2rows',
#  '_datatypes',
#  '_get_colwidths',
#  '_get_fmt',
#  '_html_fmt',
#  '_latex_fmt',
#  '_repr_html_',
#  '_repr_latex_',
#  '_txt_fmt',
#  'append',
#  'as_csv',
#  'as_html',
#  'as_latex_tabular',
#  'as_text',
#  'clear',
#  'copy',
#  'count',
#  'data',
#  'extend',
#  'extend_right',
#  'get_colwidths',
#  'index',
#  'insert',
#  'insert_header_row',
#  'insert_stubs',
#  'label_cells',
#  'output_formats',
#  'pad',
#  'pop',
#  'remove',
#  'reverse',
#  'sort',
#  'title']
